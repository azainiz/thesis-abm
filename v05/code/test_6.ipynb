# %%
import random

u = [10, 2, 1]
v = [10, 4, 1]
w = [10, 3, 1]
x = [5, 5, 2]
y = [7, 4, 1]
z = [3, 4, 1]

a = [z, w, v, x, u, y]
random.shuffle(a)

# Sort by third element (index 1), then first element (index 0)
a.sort(key=lambda item: (item[2], -item[0]))

print(a)  # Output: [[1, 1], [3, 1], [4, 1], [1, 2]]
#print([id(item) for item in a])  # Verify original references are preserved
# Out:
# [[10, 2, 1], [10, 4, 1], [10, 3, 1], [7, 4, 1], [3, 4, 1], [5, 5, 2]]

# %%
q = []
for i in range(len(q)):
    print(r)

# %%
import random

t = []
dir_list = [0, 1, 2, 3, 4]

for i in range(10):
    x = random.choice(dir_list)
    if x not in t:  # Only append if x is not already in t
        t.append(x)

print(t)
# Out:
# [1, 3, 2, 4, 0]

# %%
aa = []

# %%
bb = [1, 2]
aa.append(bb)
aa
# Out:
# [[1, 2], [1, 2]]
